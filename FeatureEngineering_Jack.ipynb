# %%
from __future__ import print_function  # Python 2 and 3
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from sklearn import linear_model
import seaborn as sns

# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
data = pd.read_csv('train.csv', index_col=0)
df = data.copy()

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
pd.DataFrame(data.isna().sum())
# Out:
#                  0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# Street           0
# ...            ...
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
#
# [80 rows x 1 columns]

# %%
numerical_var = data.select_dtypes(['int', 'float']).columns
numerical = data[numerical_var]
categorical_var = data.select_dtypes('object').columns
categorical = data[categorical_var]

# %%
features_with_na = list(numerical.columns[pd.isna(numerical).sum()>0])

for feature in features_with_na:
    print(feature, ':', np.round((numerical[feature].isna().sum())/len(numerical.index)*100, 4), '% missing')
# Out:
# LotFrontage : 17.7397 % missing
# MasVnrArea : 0.5479 % missing
# GarageYrBlt : 5.5479 % missing

# %%
data['LotFrontage'] = data['LotFrontage'].fillna(data['LotFrontage'].median())

# %%
data['MasVnrArea'] = data['MasVnrArea'].fillna(data['MasVnrArea'].mean())

# %%
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(data['GarageYrBlt'].median())

# %%
features_with_na = list(categorical.columns[pd.isna(categorical).sum()>0])

for feature in features_with_na:
    print(feature, ':', np.round((categorical[feature].isna().sum())/len(categorical.index)*100, 4), '% missing')
# Out:
# Alley : 93.7671 % missing
# MasVnrType : 0.5479 % missing
# BsmtQual : 2.5342 % missing
# BsmtCond : 2.5342 % missing
# BsmtExposure : 2.6027 % missing
# BsmtFinType1 : 2.5342 % missing
# BsmtFinType2 : 2.6027 % missing
# Electrical : 0.0685 % missing
# FireplaceQu : 47.2603 % missing
# GarageType : 5.5479 % missing
# GarageFinish : 5.5479 % missing
# GarageQual : 5.5479 % missing
# GarageCond : 5.5479 % missing
# PoolQC : 99.5205 % missing
# Fence : 80.7534 % missing
# MiscFeature : 96.3014 % missing

# %%
data = data.fillna('NA')
sum(data.isnull().sum())
# Out:
# 0

# %%
#data['Electrical'] = data['Electrical'].replace('NA',data['Electrical'].value_counts().index[0])
#data['MasVnrType'] = data['MasVnrType'].replace('NA', data['MasVnrType'].value_counts().index[0])

# %%
data[data['MasVnrType'] == 'NA']
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 235           60       RL         69.0     7851   Pave    NA      Reg
# 530           20       RL         69.0    32668   Pave    NA      IR1
# 651           60       FV         65.0     8125   Pave    NA      Reg
# 937           20       RL         67.0    10083   Pave    NA      Reg
# 974           20       FV         95.0    11639   Pave    NA      Reg
# 978          120       FV         35.0     4274   Pave  Pave      IR1
# 1244          20       RL        107.0    13891   Pave    NA      Reg
# 1279          60       RL         75.0     9473   Pave    NA      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 235          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 530          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# 651          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# ...

# %%
sum(data.isnull().sum())
# Out:
# 0

# %%
df_cat = data.select_dtypes('O')

# %%
data_no_missing = data.copy()

# %%
data = data.drop(data[data['Electrical'] == 'NA'].index)
data = data.drop(data[data['MasVnrType'] == 'NA'].index)

# %%
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave    NA      Reg
# 2             20       RL         80.0     9600   Pave    NA      Reg
# 3             60       RL         68.0    11250   Pave    NA      IR1
# 4             70       RL         60.0     9550   Pave    NA      IR1
# 5             60       RL         84.0    14260   Pave    NA      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave    NA      Reg
# 1457          20       RL         85.0    13175   Pave    NA      Reg
# 1458          70       RL         66.0     9042   Pave    NA      Reg
# 1459          20       RL         68.0     9717   Pave    NA      Reg
# 1460          20       RL         75.0     9937   Pave    NA      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
year_cols = [feature for feature in numerical_var if 'Year' in feature or 'Yr' in feature]

# %%
year_cols
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
#data['YearBuilt'] = data['YrSold'] - data['YearBuilt']

# %%
for col in year_cols[0:3]:
    data[col] = data['YrSold'] - data[col]

# %%
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave    NA      Reg
# 2             20       RL         80.0     9600   Pave    NA      Reg
# 3             60       RL         68.0    11250   Pave    NA      IR1
# 4             70       RL         60.0     9550   Pave    NA      IR1
# 5             60       RL         84.0    14260   Pave    NA      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave    NA      Reg
# 1457          20       RL         85.0    13175   Pave    NA      Reg
# 1458          70       RL         66.0     9042   Pave    NA      Reg
# 1459          20       RL         68.0     9717   Pave    NA      Reg
# 1460          20       RL         75.0     9937   Pave    NA      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
dummies = pd.get_dummies(data, drop_first=True)

# %%
# Out:
#                        SalePrice
# LotFrontage             0.333206
# LotArea                 0.264668
# OverallQual             0.790085
# YearBuilt              -0.523583
# YearRemodAdd           -0.509273
# ...                          ...
# GarageCond_TA           0.276073
# PavedDrive_Y            0.232009
# SaleType_New            0.354884
# SaleType_WD            -0.239107
# SaleCondition_Partial   0.349362
#
# [67 rows x 1 columns]

# %%
correlations = numerical.corr()
golden_corr = correlations[(correlations >= .5) | (correlations <= -.5)]
plt.figure(figsize = (12, 10))
sns.heatmap(golden_corr, cmap = 'RdYlGn', vmax = 1.0, vmin = -1.0, linewidths = .1, annot = True, annot_kws={'size': 8}, square = True)

# %%
correla
# Out:
#                MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# MSSubClass            1.0          NaN      NaN          NaN          NaN
# LotFrontage           NaN          1.0      NaN          NaN          NaN
# LotArea               NaN          NaN      1.0          NaN          NaN
# OverallQual           NaN          NaN      NaN     1.000000          NaN
# OverallCond           NaN          NaN      NaN          NaN          1.0
# YearBuilt             NaN          NaN      NaN     0.572323          NaN
# YearRemodAdd          NaN          NaN      NaN     0.550684          NaN
# MasVnrArea            NaN          NaN      NaN          NaN          NaN
# BsmtFinSF1            NaN          NaN      NaN          NaN          NaN
# BsmtFinSF2            NaN          NaN      NaN          NaN          NaN
# BsmtUnfSF             NaN          NaN      NaN          NaN          NaN
# TotalBsmtSF           NaN          NaN      NaN     0.537808          NaN
# ...

# %%
data['HouseStyle'].value_counts()[0]/len(data)
# Out:
# 0.4968986905582357

# %%
discrete = [x for x in numerical if len(numerical[x].unique()) <= 25]

# %%
for col in data[discrete].columns:
    print(f'{col}: {((data[col].value_counts()[0])/len(data))}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-02fe3c700f72> in <module>
#       1 for col in data[discrete].columns:
# ----> 2     print(f'{col}: {((data[col].value_counts()[0])/len(data))}')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
# ...

# %%
SP_corr = pd.DataFrame(correlations['SalePrice'])
SP_corr
# Out:
#                SalePrice
# MSSubClass     -0.084284
# LotFrontage     0.351799
# LotArea         0.263843
# OverallQual     0.790982
# OverallCond    -0.077856
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.477493
# BsmtFinSF1      0.386420
# BsmtFinSF2     -0.011378
# BsmtUnfSF       0.214479
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# 2ndFlrSF        0.319334
# LowQualFinSF   -0.025606
# GrLivArea       0.708624
# BsmtFullBath    0.227122
# BsmtHalfBath   -0.016844
# FullBath        0.560664
# HalfBath        0.284108
# BedroomAbvGr    0.168213
# KitchenAbvGr   -0.135907
# TotRmsAbvGrd    0.533723
# Fireplaces      0.466929
# GarageYrBlt     0.486362
# GarageCars      0.640409
# GarageArea      0.623431
# WoodDeckSF      0.324413
# OpenPorchSF     0.315856
# EnclosedPorch  -0.128578
# 3SsnPorch       0.044584
# ScreenPorch     0.111447
# PoolArea        0.092404
# MiscVal        -0.021190
# MoSold          0.046432
# YrSold         -0.028923
# ...

# %%
SP_corr[abs(SP_corr['SalePrice']) > .2].sort_values('SalePrice')
# Out:
#               SalePrice
# BsmtUnfSF      0.214479
# BsmtFullBath   0.227122
# LotArea        0.263843
# HalfBath       0.284108
# OpenPorchSF    0.315856
# 2ndFlrSF       0.319334
# WoodDeckSF     0.324413
# LotFrontage    0.351799
# BsmtFinSF1     0.386420
# Fireplaces     0.466929
# MasVnrArea     0.477493
# GarageYrBlt    0.486362
# YearRemodAdd   0.507101
# YearBuilt      0.522897
# TotRmsAbvGrd   0.533723
# FullBath       0.560664
# 1stFlrSF       0.605852
# TotalBsmtSF    0.613581
# GarageArea     0.623431
# GarageCars     0.640409
# GrLivArea      0.708624
# OverallQual    0.790982
# SalePrice      1.000000

# %%
# Out:
# 1    1384
# 2      64
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64

# %%
correlations = numerical.corr()
SP_corr = correlations[abs(correlations['SalePrice']) > .2].index

# %%
SP2 = pd.DataFrame(data[SP_corr])

# %%
SP2
# Out:
#       LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# Id
# 1            65.0     8450            7          5             5       196.0
# 2            80.0     9600            6         31            31         0.0
# 3            68.0    11250            7          7             6       162.0
# 4            60.0     9550            7         91            36         0.0
# 5            84.0    14260            8          8             8       350.0
# ...           ...      ...          ...        ...           ...         ...
# 1456         62.0     7917            6          8             7         0.0
# 1457         85.0    13175            6         32            22       119.0
# 1458         66.0     9042            7         69             4         0.0
# 1459         68.0     9717            5         60            14         0.0
# 1460         75.0     9937            5         43            43         0.0
#
# ...

# %%
SP2['LotFrontage'].corr(SP2['LotArea'])
# Out:
# 0.30469442339129416

# %%
drop = []
for i in range(len(SP2.columns) - 1):
    for j in range(len(SP2.columns) - 1):
        if SP2.iloc[:,i].corr(SP2.iloc[:,j]) > .7 and SP2.iloc[:,i].corr(SP2.iloc[:,j]) < 1:
            if SP2.iloc[:,i].corr(SP2['SalePrice']) > SP2.iloc[:,j].corr(SP2['SalePrice']):
                drop.append(SP2.columns[i])
            else:
                drop.append(SP2.columns[j])
        else:
            continue

# %%
drop = pd.DataFrame(drop)

# %%
drop[0].unique()
# Out:
# array(['LotArea', 'YearBuilt', 'GarageYrBlt', 'TotalBsmtSF', 'GrLivArea',
#        'BsmtFullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars'],
#       dtype=object)

# %%
continuous = [x for x in numerical if len(numerical[x].unique()) > 25]

# %%
for col in data[continuous].columns:
    col_mean = data[col].mean()
    col_std = data[col].std()
    cutoff = col_std * 3
    lower = col_mean - cutoff
    upper = col_mean + cutoff
    print(col)
    for x in range(len(data)):
        if data[col][x] < lower or data[col][x] > upper:
            print(x)
        else:
            continue
# Out:
# LotFrontage
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-0adaff59bfc2> in <module>
#       7     print(col)
#       8     for x in range(len(data)):
# ----> 9         if data[col][x] < lower or data[col][x] > upper:
#      10             print(x)
#      11         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
# Out:
# 65.0
