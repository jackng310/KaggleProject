# %%
from __future__ import print_function  # Python 2 and 3
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')
pd.set_option('display.max_rows', 80)

# %%
data = pd.read_csv('train.csv', index_col=0)
df = data.copy()
pd.DataFrame(data.isna().sum())
#data.select_dtypes(include=['float']).isna().sum()
# Out:
#                   0
# MSSubClass        0
# MSZoning          0
# LotFrontage     259
# LotArea           0
# Street            0
# Alley          1369
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinSF1        0
# BsmtFinType2     38
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# ...

# %%
#finding the numercial columns that are float type
na_cols= list(data.columns[data.isna().any()])
data[na_cols].select_dtypes(['float'])
#data.columns[data.isna()]
data.columns[data.isna().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
obj_df = data[na_cols].select_dtypes('object')
obj_cols = list(obj_df.columns)
#fixed_cols_df = data[na_cols].select_dtypes(['object']).replace(np.nan, 'None', regex=True)
fixed_cols = data[na_cols].select_dtypes(['object']).replace(np.nan, 'None', regex=True)
#obj_df

# %%
for col in data.columns:
    if col in obj_cols:
        data[col]= fixed_cols[col]
        
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave  None      Reg
# 2             20       RL         80.0     9600   Pave  None      Reg
# 3             60       RL         68.0    11250   Pave  None      IR1
# 4             70       RL         60.0     9550   Pave  None      IR1
# 5             60       RL         84.0    14260   Pave  None      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave  None      Reg
# 1457          20       RL         85.0    13175   Pave  None      Reg
# 1458          70       RL         66.0     9042   Pave  None      Reg
# 1459          20       RL         68.0     9717   Pave  None      Reg
# 1460          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave  None      Reg
# 2             20       RL         80.0     9600   Pave  None      Reg
# 3             60       RL         68.0    11250   Pave  None      IR1
# 4             70       RL         60.0     9550   Pave  None      IR1
# 5             60       RL         84.0    14260   Pave  None      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave  None      Reg
# 1457          20       RL         85.0    13175   Pave  None      Reg
# 1458          70       RL         66.0     9042   Pave  None      Reg
# 1459          20       RL         68.0     9717   Pave  None      Reg
# 1460          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv('train.csv')
print(df.shape)
data.head()
# Out:
# (1460, 81)
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  None      Reg
# 2           20       RL         80.0     9600   Pave  None      Reg
# 3           60       RL         68.0    11250   Pave  None      IR1
# 4           70       RL         60.0     9550   Pave  None      IR1
# 5           60       RL         84.0    14260   Pave  None      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %% [markdown]
# ### 1. Missing Values

# %%
#identify which features have missing values and what percentage of each of those features is missing
features_with_na = list(df.columns[pd.isna(df).sum()>0])

for feature in features_with_na:
    print(feature, ':', np.round((df[feature].isna().sum())/len(df.index)*100, 4), '% missing')
# Out:
# LotFrontage : 17.7397 % missing
# Alley : 93.7671 % missing
# MasVnrType : 0.5479 % missing
# MasVnrArea : 0.5479 % missing
# BsmtQual : 2.5342 % missing
# BsmtCond : 2.5342 % missing
# BsmtExposure : 2.6027 % missing
# BsmtFinType1 : 2.5342 % missing
# BsmtFinType2 : 2.6027 % missing
# Electrical : 0.0685 % missing
# FireplaceQu : 47.2603 % missing
# GarageType : 5.5479 % missing
# GarageYrBlt : 5.5479 % missing
# GarageFinish : 5.5479 % missing
# GarageQual : 5.5479 % missing
# GarageCond : 5.5479 % missing
# PoolQC : 99.5205 % missing
# Fence : 80.7534 % missing
# MiscFeature : 96.3014 % missing

# %% [markdown]
# #### Checking if there is a relationship between missing values and target

# %%
for feature in features_with_na:
    data= df.copy()
    
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.show()

# %% [markdown]
# There seems to be some relationship between missing values and sale price that we need to explore future.

# %% [markdown]
# ### Numerical Variables

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype != 'O']
numerical_features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %% [markdown]
# #### Year Variables

# %%
year_features = [feature for feature in numerical_features if 'Year' in feature or 'Yr' in feature]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_features:
    data = df.copy()
    data.groupby(feature)['SalePrice'].median().plot()
    plt.show()

# %% [markdown]
# #### Discrete Variables

# %%
discrete_features = [feature for feature in numerical_features if len(df[feature].unique()) < 25 and feature not in year_features+['Id']]
discrete_features
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
#comparing discrete features with sale price

for feature in discrete_features:
    data = df.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.show()

# %% [markdown]
# #### Continuous Variables

# %%
continuous_features=[feature for feature in numerical_features if feature not in discrete_features+['Id'] and feature not in year_features]
continuous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
#looking at distribution of continuous variables and sale price

for feature in continuous_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.show()

# %%
np.log(data['LotFrontage'])
# Out:
# 0       4.174387
# 1       4.382027
# 2       4.219508
# 3       4.094345
# 4       4.430817
#           ...
# 1455    4.127134
# 1456    4.442651
# 1457    4.189655
# 1458    4.219508
# 1459    4.317488
# Name: LotFrontage, Length: 1460, dtype: float64

# %% [markdown]
# #### Outliers

# %%
for feature in continuous_features:
    data=df.copy()
    data[feature] = data[feature]
    plt.scatter(data[feature], data['SalePrice'])
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# #### Categorical

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtypes == 'O']

# %%
num_categorical = pd.DataFrame((zip(categorical_features,[len(df[feature].unique()) for feature in categorical_features])))
num_categorical.columns = ['Feature', 'Unique']
num_categorical
# Out:
#           Feature  Unique
# 0        MSZoning       5
# 1          Street       2
# 2           Alley       3
# 3        LotShape       4
# 4     LandContour       4
# 5       Utilities       2
# 6       LotConfig       5
# 7       LandSlope       3
# 8    Neighborhood      25
# 9      Condition1       9
# 10     Condition2       8
# 11       BldgType       5
# 12     HouseStyle       8
# 13      RoofStyle       6
# 14       RoofMatl       8
# 15    Exterior1st      15
# 16    Exterior2nd      16
# 17     MasVnrType       5
# 18      ExterQual       4
# 19      ExterCond       5
# 20     Foundation       6
# 21       BsmtQual       5
# 22       BsmtCond       5
# 23   BsmtExposure       5
# 24   BsmtFinType1       7
# 25   BsmtFinType2       7
# 26        Heating       6
# 27      HeatingQC       5
# 28     CentralAir       2
# 29     Electrical       6
# 30    KitchenQual       4
# 31     Functional       7
# 32    FireplaceQu       6
# 33     GarageType       7
# ...

# %%
#comparing categorical features to sale price

for feature in categorical_features:
    data = df.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.show()

# %%
list(df.columns[pd.isna(df).sum()>0])
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
[feature for feature in df.columns if (data[feature].dtypes == 'O') and (feature in features_with_na)]
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# ### Checking for Dominant unique features

# %%
dom_check=[]
for feature in categorical_features:
    percent = df[feature].value_counts()[0]/len(df)
    dom_check.append(percent)

# %%
categorical_percent = pd.DataFrame(list(zip(categorical_features, dom_check)))
categorical_percent.columns = ['Feature', 'Top Feature Percentage']
categorical_percent
# Out:
#           Feature  Top Feature Percentage
# 0        MSZoning                0.788356
# 1          Street                0.995890
# 2           Alley                0.034247
# 3        LotShape                0.633562
# 4     LandContour                0.897945
# 5       Utilities                0.999315
# 6       LotConfig                0.720548
# 7       LandSlope                0.946575
# 8    Neighborhood                0.154110
# 9      Condition1                0.863014
# 10     Condition2                0.989726
# 11       BldgType                0.835616
# 12     HouseStyle                0.497260
# 13      RoofStyle                0.781507
# 14       RoofMatl                0.982192
# 15    Exterior1st                0.352740
# 16    Exterior2nd                0.345205
# 17     MasVnrType                0.591781
# 18      ExterQual                0.620548
# 19      ExterCond                0.878082
# 20     Foundation                0.443151
# ...

# %%
sns.barplot(x='Top Feature Percentage', y ='Feature', data=categorical_percent)
sns.set(rc={'figure.figsize':(15,15)})

# %%
df['PoolQC'].value_counts()
# Out:
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
